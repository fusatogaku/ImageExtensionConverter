# %%
# GUI
import tkinter as tk
import sys, time
# function
from PIL import Image
import glob
import os

root = tk.Tk()

# -------関数エリア-------
def btn_click(event): 
    """
    ボタンクリックした時の処理
    """
    statusbar['text'] = 'converting...'
    folderPath = input_box.get()
    conv(folderPath, var_origin.get(), var_converted.get())
    statusbar['text'] = 'complete!'


def conv(folderPath, o, conv) -> None:
    """
    変換処理
    """
    files = glob.glob(folderPath + f'/*.{o}')

    if len(files) == 0:
        statusbar['text'] = 'No webp files were found in the directory.'
        return
    
    for _ in files:
        im = Image.open(_).convert('RGB')
        rename = os.path.splitext(_)[0] + f'.{conv}'
        im.save(rename)
        os.remove(_)
    
# -------タイトルラベル-------
root.title('image converter.exe')
# -------画面サイズ-------
root.geometry('500x200')


# -------拡張子選択（オリジナル）-------
OptionList = [
    'jpg',
    'png',
    'webp',
    'ico',
    'bmp',
    'gif',
]
var_origin = tk.StringVar(root)
var_origin.set(OptionList[0])

lbl_orijinl = tk.Label(text=u'拡張子選択(変換前)')
lbl_orijinl.place(x=10,y=0)
original = tk.OptionMenu(root, var_origin, *OptionList)
original.place(x=10, y=20)
# -------拡張子選択（変換先）-------
var_converted = tk.StringVar(root)
var_converted.set(OptionList[1])

lbl_converted = tk.Label(text=u'拡張子選択(変換前)')
lbl_converted.place(x=150,y=0)
converted = tk.OptionMenu(root, var_converted, *OptionList)
converted.place(x=150, y=20)

# -------フォルダパス-------
lbl = tk.Label(text=u'フォルダのフルパス')
lbl.place(x=10, y=80)
input_box = tk.Entry(width=70)
input_box.place(x=10, y=105)

# -------実行ボタン-------
btn = tk.Button(root, text="変換実行")
btn.place(x=10, y=150)
btn.bind('<Button-1>', btn_click)


# -------ステータスバー設置-------
statusbar = tk.Label(root, text="0/0")
statusbar.pack(side = tk.BOTTOM, fill = tk.X)

root.mainloop()

# %%
"""
・変換するファイルの拡張子
・変換したいファイルの拡張子
・フォルダパス
・実行ボタン
"""
OptionList = [
    'jpg',
    'png',
    'gif',
    'bmp',
    'webp',
    'ico',
]
# 変換するファイルの拡張子選択
var = tk.StringVar(root)
var.set(OptionList[0])
original = tk.OptionMenu(root, extentions, *OptionList)
original.place(x=10, y=20)
converted = tk.OptionMenu(root, extentions, *OptionList)
converted.place(x=300, y=20)
# フォルダパス
# lbl_entry = tk.Label(text=u'画像が入ったフォルダのフルパス')
# lbl_entry.place(x=10, y=0)
# entry = tk.Entry(width=70)
# entry.place(x=10, y=20)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-40-0b563dee8903> in <module>
#      16 var = tk.StringVar(root)
#      17 var.set(OptionList[0])
# ---> 18 original = tk.OptionMenu(root, extentions, *OptionList)
#      19 original.place(x=10, y=20)
#      20 converted = tk.OptionMenu(root, extentions, *OptionList)
#
# c:\Users\zektb\anaconda3\lib\tkinter\__init__.py in __init__(self, master, variable, value, *values, **kwargs)
#    3955               "indicatoron": 1, "relief": RAISED, "anchor": "c",
#    3956               "highlightthickness": 2}
# -> 3957         Widget.__init__(self, master, "menubutton", kw)
#    3958         self.widgetName = 'tk_optionMenu'
#    3959         menu = self.__menu = Menu(self, name="menu", tearoff=0)
#
# c:\Users\zektb\anaconda3\lib\tkinter\__init__.py in __init__(self, master, widgetName, cnf, kw, extra)
#    2565         for k, v in classes:
#    2566             del cnf[k]
# -> 2567         self.tk.call(
#    2568             (widgetName, self._w) + extra + self._options(cnf))
#    2569         for k, v in classes:
#
# TclError: can't invoke "menubutton" command: application has been destroyed
